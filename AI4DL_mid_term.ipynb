# %% [markdown]
# <a href="https://colab.research.google.com/github/Chae-yoonsik/123/blob/main/AI4DL_mid_term.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mid-term exam on AI for Deep Learning
#
# - Name: 채윤식
# - ID Number:  20192223
#
# ------------------------------------------
# Firstly, copy this notebook to your google drive.
# Secondly, click 'Runtime' tab, 'Change runtime type' tab, and change 'Hardware accelerator' as 'GPU.'
# Now you are ready to go, good luck! :)

# %%
import tensorflow as tf
tf.keras.__version__
# Out:
# '2.12.0'

# %% [markdown]
# ## Generating data for the exam

# %%
from sklearn.datasets import make_moons

inputs, targets = make_moons(n_samples=5000, noise=0.1)
inputs_dev, targets_dev = make_moons(n_samples=1000, noise=0.1)

import matplotlib.pyplot as plt
plt.scatter(inputs[:, 0], inputs[:, 1], c=targets)
plt.show()

# %% [markdown]
# ## Q1 We will use the generated data
#
# Inputs and targets are training data, and inputs_dev and targets_dev are validation data.

# %% [markdown]
# #### (Q1-1) [15 points] Check your data and design your neural network model
#   - [5] Check dimension of inputs and targets.
#   - [5] Design a simple model using one hidden dense layer.
#     - Your hidden dense layer have dimension 3 with relu activation
#     - Set the proper activation for binary outcome (0 or 1)
# ![image.png](data:image/png;base64,...)
#   - [5] Build your model and check model summary. The result should look like:
#
#   ![image.png](data:image/png;base64,...)

# %%
## change the code below to check dimension

inputs.ndim
# Out:
# 2

# %%
## change the code below to check dimension

targets.ndim
# Out:
# 1

# %%
from tensorflow.keras import models
from tensorflow.keras import layers

model = models.Sequential([
    layers.Dense(3, activation="relu"),
    layers.Dense(1, activation="sigmoid")
## your code here

])

# %%
## Build your model, and check the summary. your code here
from tensorflow import keras
from tensorflow.keras import layers

model_1 = keras.Sequential(name="sequential_8")
model_1.add(layers.Dense(3, activation="relu", name="dense_52"))
model_1.add(layers.Dense(1, activation="sigmoid", name="dense_53"))

model_1.build(input_shape=(None, 2))
model_1.weights
model_1.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_52 (Dense)            (None, 3)                 9
#
#  dense_53 (Dense)            (None, 1)                 4
#
# =================================================================
# Total params: 13
# Trainable params: 13
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### (Q1-2) [12 points] Compile your model.
#  - [4] Setup optimizer as 'SGD'
#  - [4] Use binary cross entropy loss.
#  - [4] Set your evaluation metric as 'accuracy'

# %%
### Define optimizer, loss, and metrics here
model_1.compile(optimizer="SGD",
              loss="binary_crossentropy",
              metrics=["accuracy"]
)

# %% [markdown]
# #### (Q1-3) [8 points] Train your model and check results.
#  - [4]  Fit your model using 100 number of epochs with batch size 100. Specify validation data using _inputs_dev_ and _targets_dev_ datasets.
#  - [4] Evaluate your model using _inputs_dev_ and _targets_dev_.

# %%
history = model_1.fit(    
    inputs, targets,
    epochs=100,
    batch_size=100,
    validation_data=(inputs_dev, targets_dev))
    ### Your code here
# Out:
# Epoch 1/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.2497 - accuracy: 0.8936 - val_loss: 0.2544 - val_accuracy: 0.8950
# Epoch 2/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2491 - accuracy: 0.8932 - val_loss: 0.2539 - val_accuracy: 0.8950
# Epoch 3/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.2487 - accuracy: 0.8936 - val_loss: 0.2535 - val_accuracy: 0.8950
# Epoch 4/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2482 - accuracy: 0.8936 - val_loss: 0.2530 - val_accuracy: 0.8960
# Epoch 5/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.2477 - accuracy: 0.8932 - val_loss: 0.2525 - val_accuracy: 0.8960
# Epoch 6/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2473 - accuracy: 0.8936 - val_loss: 0.2520 - val_accuracy: 0.8960
# Epoch 7/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2468 - accuracy: 0.8942 - val_loss: 0.2516 - val_accuracy: 0.8970
# Epoch 8/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2464 - accuracy: 0.8942 - val_loss: 0.2512 - val_accuracy: 0.8970
# Epoch 9/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2460 - accuracy: 0.8944 - val_loss: 0.2507 - val_accuracy: 0.8970
# Epoch 10/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.2455 - accuracy: 0.8944 - val_loss: 0.2503 - val_accuracy: 0.8970
# Epoch 11/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2451 - accuracy: 0.8948 - val_loss: 0.2499 - val_accuracy: 0.8970
# Epoch 12/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2447 - accuracy: 0.8944 - val_loss: 0.2494 - val_accuracy: 0.8970
# Epoch 13/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2443 - accuracy: 0.8944 - val_loss: 0.2490 - val_accuracy: 0.8970
# Epoch 14/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2438 - accuracy: 0.8946 - val_loss: 0.2487 - val_accuracy: 0.8980
# Epoch 15/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2435 - accuracy: 0.8944 - val_loss: 0.2483 - val_accuracy: 0.8980
# Epoch 16/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.2431 - accuracy: 0.8948 - val_loss: 0.2479 - val_accuracy: 0.8990
# Epoch 17/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2427 - accuracy: 0.8950 - val_loss: 0.2475 - val_accuracy: 0.8990
# Epoch 18/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2423 - accuracy: 0.8948 - val_loss: 0.2471 - val_accuracy: 0.8990
# Epoch 19/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2419 - accuracy: 0.8948 - val_loss: 0.2467 - val_accuracy: 0.8990
# Epoch 20/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2415 - accuracy: 0.8952 - val_loss: 0.2463 - val_accuracy: 0.8990
# Epoch 21/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2411 - accuracy: 0.8952 - val_loss: 0.2459 - val_accuracy: 0.9000
# Epoch 22/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2407 - accuracy: 0.8956 - val_loss: 0.2455 - val_accuracy: 0.8990
# Epoch 23/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.2404 - accuracy: 0.8958 - val_loss: 0.2452 - val_accuracy: 0.8990
# Epoch 24/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2400 - accuracy: 0.8956 - val_loss: 0.2448 - val_accuracy: 0.9000
# Epoch 25/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2396 - accuracy: 0.8958 - val_loss: 0.2445 - val_accuracy: 0.9000
# Epoch 26/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2392 - accuracy: 0.8958 - val_loss: 0.2441 - val_accuracy: 0.9000
# Epoch 27/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2389 - accuracy: 0.8960 - val_loss: 0.2438 - val_accuracy: 0.9000
# Epoch 28/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2385 - accuracy: 0.8966 - val_loss: 0.2434 - val_accuracy: 0.9000
# Epoch 29/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2382 - accuracy: 0.8966 - val_loss: 0.2431 - val_accuracy: 0.9000
# Epoch 30/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2378 - accuracy: 0.8962 - val_loss: 0.2427 - val_accuracy: 0.9000
# Epoch 31/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2374 - accuracy: 0.8968 - val_loss: 0.2424 - val_accuracy: 0.9000
# Epoch 32/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2371 - accuracy: 0.8972 - val_loss: 0.2420 - val_accuracy: 0.8990
# Epoch 33/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2367 - accuracy: 0.8968 - val_loss: 0.2417 - val_accuracy: 0.9000
# Epoch 34/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2364 - accuracy: 0.8978 - val_loss: 0.2413 - val_accuracy: 0.9000
# Epoch 35/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2361 - accuracy: 0.8974 - val_loss: 0.2410 - val_accuracy: 0.9000
# Epoch 36/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2357 - accuracy: 0.8982 - val_loss: 0.2407 - val_accuracy: 0.9010
# Epoch 37/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.2354 - accuracy: 0.8980 - val_loss: 0.2404 - val_accuracy: 0.9010
# Epoch 38/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.2350 - accuracy: 0.8982 - val_loss: 0.2400 - val_accuracy: 0.9000
# Epoch 39/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2347 - accuracy: 0.8976 - val_loss: 0.2397 - val_accuracy: 0.9000
# Epoch 40/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2344 - accuracy: 0.8978 - val_loss: 0.2393 - val_accuracy: 0.9000
# Epoch 41/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2340 - accuracy: 0.8978 - val_loss: 0.2390 - val_accuracy: 0.9000
# Epoch 42/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2337 - accuracy: 0.8982 - val_loss: 0.2387 - val_accuracy: 0.9010
# Epoch 43/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2334 - accuracy: 0.8988 - val_loss: 0.2384 - val_accuracy: 0.9000
# Epoch 44/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2330 - accuracy: 0.8984 - val_loss: 0.2381 - val_accuracy: 0.9010
# Epoch 45/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.2327 - accuracy: 0.8986 - val_loss: 0.2377 - val_accuracy: 0.9010
# Epoch 46/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2324 - accuracy: 0.8992 - val_loss: 0.2374 - val_accuracy: 0.9000
# Epoch 47/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2320 - accuracy: 0.8986 - val_loss: 0.2370 - val_accuracy: 0.9000
# Epoch 48/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2317 - accuracy: 0.8988 - val_loss: 0.2367 - val_accuracy: 0.9000
# Epoch 49/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2313 - accuracy: 0.8986 - val_loss: 0.2364 - val_accuracy: 0.9000
# Epoch 50/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2310 - accuracy: 0.8990 - val_loss: 0.2361 - val_accuracy: 0.9000
# Epoch 51/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2307 - accuracy: 0.8994 - val_loss: 0.2358 - val_accuracy: 0.9000
# Epoch 52/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.2304 - accuracy: 0.8998 - val_loss: 0.2355 - val_accuracy: 0.9000
# Epoch 53/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2301 - accuracy: 0.8994 - val_loss: 0.2351 - val_accuracy: 0.9000
# Epoch 54/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.2298 - accuracy: 0.8998 - val_loss: 0.2348 - val_accuracy: 0.9000
# Epoch 55/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.2294 - accuracy: 0.8998 - val_loss: 0.2345 - val_accuracy: 0.9000
# Epoch 56/100
# 50/50 [==============================] - 0s 6ms/step - loss: 0.2291 - accuracy: 0.9002 - val_loss: 0.2342 - val_accuracy: 0.9010
# Epoch 57/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.2288 - accuracy: 0.9006 - val_loss: 0.2339 - val_accuracy: 0.9010
# Epoch 58/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.2284 - accuracy: 0.9004 - val_loss: 0.2336 - val_accuracy: 0.9020
# Epoch 59/100
# 50/50 [==============================] - 0s 6ms/step - loss: 0.2281 - accuracy: 0.9002 - val_loss: 0.2333 - val_accuracy: 0.9020
# Epoch 60/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.2278 - accuracy: 0.9008 - val_loss: 0.2329 - val_accuracy: 0.9020
# Epoch 61/100
# 50/50 [==============================] - 0s 6ms/step - loss: 0.2275 - accuracy: 0.9012 - val_loss: 0.2326 - val_accuracy: 0.9030
# Epoch 62/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.2271 - accuracy: 0.9010 - val_loss: 0.2322 - val_accuracy: 0.9020
# Epoch 63/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2268 - accuracy: 0.9020 - val_loss: 0.2319 - val_accuracy: 0.9030
# Epoch 64/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2265 - accuracy: 0.9022 - val_loss: 0.2316 - val_accuracy: 0.9030
# Epoch 65/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2261 - accuracy: 0.9018 - val_loss: 0.2314 - val_accuracy: 0.9030
# Epoch 66/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2258 - accuracy: 0.9014 - val_loss: 0.2310 - val_accuracy: 0.9040
# Epoch 67/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.2255 - accuracy: 0.9012 - val_loss: 0.2307 - val_accuracy: 0.9030
# Epoch 68/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2252 - accuracy: 0.9016 - val_loss: 0.2304 - val_accuracy: 0.9030
# Epoch 69/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.2249 - accuracy: 0.9024 - val_loss: 0.2300 - val_accuracy: 0.9040
# Epoch 70/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2246 - accuracy: 0.9020 - val_loss: 0.2297 - val_accuracy: 0.9050
# Epoch 71/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.2242 - accuracy: 0.9028 - val_loss: 0.2294 - val_accuracy: 0.9040
# Epoch 72/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2239 - accuracy: 0.9024 - val_loss: 0.2290 - val_accuracy: 0.9050
# Epoch 73/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2236 - accuracy: 0.9028 - val_loss: 0.2287 - val_accuracy: 0.9040
# Epoch 74/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2232 - accuracy: 0.9024 - val_loss: 0.2284 - val_accuracy: 0.9040
# Epoch 75/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2229 - accuracy: 0.9032 - val_loss: 0.2281 - val_accuracy: 0.9040
# Epoch 76/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2226 - accuracy: 0.9032 - val_loss: 0.2277 - val_accuracy: 0.9050
# Epoch 77/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2223 - accuracy: 0.9034 - val_loss: 0.2274 - val_accuracy: 0.9050
# Epoch 78/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2219 - accuracy: 0.9036 - val_loss: 0.2271 - val_accuracy: 0.9050
# Epoch 79/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.2216 - accuracy: 0.9034 - val_loss: 0.2268 - val_accuracy: 0.9050
# Epoch 80/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2213 - accuracy: 0.9034 - val_loss: 0.2264 - val_accuracy: 0.9050
# Epoch 81/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2209 - accuracy: 0.9044 - val_loss: 0.2261 - val_accuracy: 0.9050
# Epoch 82/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2206 - accuracy: 0.9046 - val_loss: 0.2258 - val_accuracy: 0.9050
# Epoch 83/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2203 - accuracy: 0.9042 - val_loss: 0.2254 - val_accuracy: 0.9050
# Epoch 84/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.2199 - accuracy: 0.9046 - val_loss: 0.2251 - val_accuracy: 0.9040
# Epoch 85/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2196 - accuracy: 0.9052 - val_loss: 0.2247 - val_accuracy: 0.9050
# Epoch 86/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2192 - accuracy: 0.9050 - val_loss: 0.2244 - val_accuracy: 0.9050
# Epoch 87/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2189 - accuracy: 0.9056 - val_loss: 0.2240 - val_accuracy: 0.9060
# Epoch 88/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.2185 - accuracy: 0.9060 - val_loss: 0.2238 - val_accuracy: 0.9050
# Epoch 89/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2182 - accuracy: 0.9062 - val_loss: 0.2234 - val_accuracy: 0.9050
# Epoch 90/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2178 - accuracy: 0.9056 - val_loss: 0.2231 - val_accuracy: 0.9050
# Epoch 91/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2175 - accuracy: 0.9054 - val_loss: 0.2227 - val_accuracy: 0.9050
# Epoch 92/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2171 - accuracy: 0.9058 - val_loss: 0.2223 - val_accuracy: 0.9070
# Epoch 93/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2168 - accuracy: 0.9074 - val_loss: 0.2220 - val_accuracy: 0.9080
# Epoch 94/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2165 - accuracy: 0.9070 - val_loss: 0.2216 - val_accuracy: 0.9070
# Epoch 95/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2161 - accuracy: 0.9066 - val_loss: 0.2213 - val_accuracy: 0.9050
# Epoch 96/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.2157 - accuracy: 0.9074 - val_loss: 0.2209 - val_accuracy: 0.9070
# Epoch 97/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2154 - accuracy: 0.9078 - val_loss: 0.2206 - val_accuracy: 0.9070
# Epoch 98/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2150 - accuracy: 0.9078 - val_loss: 0.2202 - val_accuracy: 0.9070
# Epoch 99/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.2146 - accuracy: 0.9078 - val_loss: 0.2199 - val_accuracy: 0.9090
# Epoch 100/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2143 - accuracy: 0.9078 - val_loss: 0.2195 - val_accuracy: 0.9090

# %%
## Evaluate your model. Your code here:
test_loss, test_acc = model_1.evaluate(inputs_dev, targets_dev)
print(f"[{test_loss}, {test_acc}]")
# Out:
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2106 - accuracy: 0.9040
# [0.21063455939292908, 0.9039999842643738]

# %% [markdown]
# #### (Q1-4) [10 points] The current accuracy is not so good. Let's try having nine hidden dense layers to improve the model.
#   - Train and evaluate the model as done before.
#   - Try to visualzie the results.(sample visualization codes provided below)
# ![image.png](data:image/png;base64,...)

# %%
## Plot of the ground truth set
import matplotlib.pyplot as plt
plt.scatter(inputs_dev[:, 0], inputs_dev[:, 1], c=targets_dev)
plt.show()

# %%
## Plot of your model
## replace the result with your upgraded model
import matplotlib.pyplot as plt
res1 = model.predict(inputs_dev)
decision1 = res1 > .5
plt.scatter(inputs_dev[:, 0], inputs_dev[:, 1], c=decision1)
plt.show()
# Out:
# 32/32 [==============================] - 0s 2ms/step

# %%
model = models.Sequential([
    layers.Dense(3, activation="relu"),
    layers.Dense(3, activation="relu"),
    layers.Dense(3, activation="relu"),
    layers.Dense(3, activation="relu"),
    layers.Dense(3, activation="relu"),
    layers.Dense(3, activation="relu"),
    layers.Dense(3, activation="relu"),
    layers.Dense(3, activation="relu"),
    layers.Dense(3, activation="relu"),    
    layers.Dense(1, activation="sigmoid")

## define your new model here

])

# %%
### Define optimizer, loss, and metrics here
model.compile(optimizer="SGD",
              loss="binary_crossentropy",
              metrics=["accuracy"]
)

# %%
history = model_1.fit(    
    inputs, targets,
    epochs=100,
    batch_size=100,
    validation_data=(inputs_dev, targets_dev))
    ### Your code here
# Out:
# Epoch 1/100
# 50/50 [==============================] - 0s 6ms/step - loss: 0.2180 - accuracy: 0.9022 - val_loss: 0.2102 - val_accuracy: 0.9040
# Epoch 2/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.2176 - accuracy: 0.9030 - val_loss: 0.2099 - val_accuracy: 0.9040
# Epoch 3/100
# 50/50 [==============================] - 0s 6ms/step - loss: 0.2173 - accuracy: 0.9026 - val_loss: 0.2095 - val_accuracy: 0.9050
# Epoch 4/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.2169 - accuracy: 0.9030 - val_loss: 0.2093 - val_accuracy: 0.9060
# Epoch 5/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2165 - accuracy: 0.9030 - val_loss: 0.2088 - val_accuracy: 0.9060
# Epoch 6/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.2161 - accuracy: 0.9032 - val_loss: 0.2085 - val_accuracy: 0.9060
# Epoch 7/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2157 - accuracy: 0.9034 - val_loss: 0.2081 - val_accuracy: 0.9070
# Epoch 8/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2153 - accuracy: 0.9040 - val_loss: 0.2077 - val_accuracy: 0.9070
# Epoch 9/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2149 - accuracy: 0.9038 - val_loss: 0.2073 - val_accuracy: 0.9070
# Epoch 10/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.2146 - accuracy: 0.9034 - val_loss: 0.2069 - val_accuracy: 0.9070
# Epoch 11/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2142 - accuracy: 0.9042 - val_loss: 0.2065 - val_accuracy: 0.9070
# Epoch 12/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2137 - accuracy: 0.9044 - val_loss: 0.2060 - val_accuracy: 0.9070
# Epoch 13/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2133 - accuracy: 0.9040 - val_loss: 0.2059 - val_accuracy: 0.9090
# Epoch 14/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2130 - accuracy: 0.9046 - val_loss: 0.2055 - val_accuracy: 0.9090
# Epoch 15/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2126 - accuracy: 0.9042 - val_loss: 0.2051 - val_accuracy: 0.9090
# Epoch 16/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2121 - accuracy: 0.9042 - val_loss: 0.2049 - val_accuracy: 0.9110
# Epoch 17/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2118 - accuracy: 0.9054 - val_loss: 0.2043 - val_accuracy: 0.9100
# Epoch 18/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2113 - accuracy: 0.9052 - val_loss: 0.2038 - val_accuracy: 0.9100
# Epoch 19/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.2109 - accuracy: 0.9054 - val_loss: 0.2034 - val_accuracy: 0.9100
# Epoch 20/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2105 - accuracy: 0.9050 - val_loss: 0.2032 - val_accuracy: 0.9120
# Epoch 21/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.2101 - accuracy: 0.9056 - val_loss: 0.2028 - val_accuracy: 0.9130
# Epoch 22/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2097 - accuracy: 0.9062 - val_loss: 0.2023 - val_accuracy: 0.9120
# Epoch 23/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2093 - accuracy: 0.9066 - val_loss: 0.2018 - val_accuracy: 0.9120
# Epoch 24/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2088 - accuracy: 0.9068 - val_loss: 0.2013 - val_accuracy: 0.9120
# Epoch 25/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2084 - accuracy: 0.9062 - val_loss: 0.2008 - val_accuracy: 0.9120
# Epoch 26/100
# 50/50 [==============================] - 0s 6ms/step - loss: 0.2080 - accuracy: 0.9062 - val_loss: 0.2005 - val_accuracy: 0.9120
# Epoch 27/100
# 50/50 [==============================] - 0s 7ms/step - loss: 0.2076 - accuracy: 0.9066 - val_loss: 0.2002 - val_accuracy: 0.9130
# Epoch 28/100
# 50/50 [==============================] - 0s 6ms/step - loss: 0.2071 - accuracy: 0.9074 - val_loss: 0.1997 - val_accuracy: 0.9120
# Epoch 29/100
# 50/50 [==============================] - 0s 7ms/step - loss: 0.2066 - accuracy: 0.9082 - val_loss: 0.1991 - val_accuracy: 0.9120
# Epoch 30/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.2062 - accuracy: 0.9070 - val_loss: 0.1988 - val_accuracy: 0.9120
# Epoch 31/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2058 - accuracy: 0.9076 - val_loss: 0.1984 - val_accuracy: 0.9120
# Epoch 32/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2053 - accuracy: 0.9078 - val_loss: 0.1979 - val_accuracy: 0.9140
# Epoch 33/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2049 - accuracy: 0.9076 - val_loss: 0.1976 - val_accuracy: 0.9140
# Epoch 34/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2044 - accuracy: 0.9084 - val_loss: 0.1971 - val_accuracy: 0.9140
# Epoch 35/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2039 - accuracy: 0.9086 - val_loss: 0.1965 - val_accuracy: 0.9130
# Epoch 36/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2035 - accuracy: 0.9086 - val_loss: 0.1961 - val_accuracy: 0.9140
# Epoch 37/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2031 - accuracy: 0.9098 - val_loss: 0.1957 - val_accuracy: 0.9140
# Epoch 38/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.2026 - accuracy: 0.9100 - val_loss: 0.1952 - val_accuracy: 0.9140
# Epoch 39/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2021 - accuracy: 0.9104 - val_loss: 0.1948 - val_accuracy: 0.9140
# Epoch 40/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2016 - accuracy: 0.9096 - val_loss: 0.1944 - val_accuracy: 0.9140
# Epoch 41/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.2011 - accuracy: 0.9108 - val_loss: 0.1938 - val_accuracy: 0.9140
# Epoch 42/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2007 - accuracy: 0.9108 - val_loss: 0.1934 - val_accuracy: 0.9140
# Epoch 43/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2002 - accuracy: 0.9120 - val_loss: 0.1930 - val_accuracy: 0.9140
# Epoch 44/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1997 - accuracy: 0.9122 - val_loss: 0.1925 - val_accuracy: 0.9140
# Epoch 45/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1992 - accuracy: 0.9122 - val_loss: 0.1919 - val_accuracy: 0.9140
# Epoch 46/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1987 - accuracy: 0.9124 - val_loss: 0.1914 - val_accuracy: 0.9140
# Epoch 47/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1982 - accuracy: 0.9130 - val_loss: 0.1910 - val_accuracy: 0.9150
# Epoch 48/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1977 - accuracy: 0.9140 - val_loss: 0.1904 - val_accuracy: 0.9150
# Epoch 49/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1972 - accuracy: 0.9134 - val_loss: 0.1900 - val_accuracy: 0.9160
# Epoch 50/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1967 - accuracy: 0.9136 - val_loss: 0.1896 - val_accuracy: 0.9160
# Epoch 51/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1962 - accuracy: 0.9146 - val_loss: 0.1892 - val_accuracy: 0.9180
# Epoch 52/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1957 - accuracy: 0.9158 - val_loss: 0.1884 - val_accuracy: 0.9180
# Epoch 53/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1952 - accuracy: 0.9146 - val_loss: 0.1881 - val_accuracy: 0.9190
# Epoch 54/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1947 - accuracy: 0.9150 - val_loss: 0.1876 - val_accuracy: 0.9190
# Epoch 55/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1942 - accuracy: 0.9166 - val_loss: 0.1871 - val_accuracy: 0.9210
# Epoch 56/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1937 - accuracy: 0.9160 - val_loss: 0.1865 - val_accuracy: 0.9210
# Epoch 57/100
# 50/50 [==============================] - 0s 6ms/step - loss: 0.1931 - accuracy: 0.9174 - val_loss: 0.1860 - val_accuracy: 0.9220
# Epoch 58/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.1926 - accuracy: 0.9178 - val_loss: 0.1854 - val_accuracy: 0.9210
# Epoch 59/100
# 50/50 [==============================] - 0s 6ms/step - loss: 0.1921 - accuracy: 0.9176 - val_loss: 0.1849 - val_accuracy: 0.9220
# Epoch 60/100
# 50/50 [==============================] - 0s 6ms/step - loss: 0.1916 - accuracy: 0.9178 - val_loss: 0.1845 - val_accuracy: 0.9220
# Epoch 61/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.1910 - accuracy: 0.9182 - val_loss: 0.1839 - val_accuracy: 0.9230
# Epoch 62/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.1905 - accuracy: 0.9184 - val_loss: 0.1834 - val_accuracy: 0.9230
# Epoch 63/100
# 50/50 [==============================] - 0s 6ms/step - loss: 0.1899 - accuracy: 0.9194 - val_loss: 0.1830 - val_accuracy: 0.9250
# Epoch 64/100
# 50/50 [==============================] - 0s 6ms/step - loss: 0.1894 - accuracy: 0.9202 - val_loss: 0.1822 - val_accuracy: 0.9240
# Epoch 65/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1889 - accuracy: 0.9196 - val_loss: 0.1818 - val_accuracy: 0.9250
# Epoch 66/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1883 - accuracy: 0.9200 - val_loss: 0.1812 - val_accuracy: 0.9260
# Epoch 67/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1878 - accuracy: 0.9202 - val_loss: 0.1807 - val_accuracy: 0.9260
# Epoch 68/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1872 - accuracy: 0.9200 - val_loss: 0.1802 - val_accuracy: 0.9270
# Epoch 69/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1867 - accuracy: 0.9204 - val_loss: 0.1797 - val_accuracy: 0.9270
# Epoch 70/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1861 - accuracy: 0.9208 - val_loss: 0.1790 - val_accuracy: 0.9270
# Epoch 71/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1856 - accuracy: 0.9208 - val_loss: 0.1786 - val_accuracy: 0.9270
# Epoch 72/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1850 - accuracy: 0.9216 - val_loss: 0.1780 - val_accuracy: 0.9270
# Epoch 73/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1844 - accuracy: 0.9214 - val_loss: 0.1775 - val_accuracy: 0.9270
# Epoch 74/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1839 - accuracy: 0.9220 - val_loss: 0.1769 - val_accuracy: 0.9270
# Epoch 75/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1833 - accuracy: 0.9232 - val_loss: 0.1763 - val_accuracy: 0.9280
# Epoch 76/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1827 - accuracy: 0.9230 - val_loss: 0.1756 - val_accuracy: 0.9270
# Epoch 77/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1822 - accuracy: 0.9238 - val_loss: 0.1751 - val_accuracy: 0.9280
# Epoch 78/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1816 - accuracy: 0.9248 - val_loss: 0.1747 - val_accuracy: 0.9280
# Epoch 79/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1810 - accuracy: 0.9248 - val_loss: 0.1740 - val_accuracy: 0.9290
# Epoch 80/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1804 - accuracy: 0.9254 - val_loss: 0.1734 - val_accuracy: 0.9290
# Epoch 81/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1798 - accuracy: 0.9264 - val_loss: 0.1728 - val_accuracy: 0.9290
# Epoch 82/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1793 - accuracy: 0.9264 - val_loss: 0.1723 - val_accuracy: 0.9290
# Epoch 83/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1786 - accuracy: 0.9266 - val_loss: 0.1719 - val_accuracy: 0.9300
# Epoch 84/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1781 - accuracy: 0.9274 - val_loss: 0.1711 - val_accuracy: 0.9310
# Epoch 85/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1775 - accuracy: 0.9278 - val_loss: 0.1707 - val_accuracy: 0.9310
# Epoch 86/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1769 - accuracy: 0.9276 - val_loss: 0.1700 - val_accuracy: 0.9330
# Epoch 87/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1763 - accuracy: 0.9280 - val_loss: 0.1694 - val_accuracy: 0.9340
# Epoch 88/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1757 - accuracy: 0.9288 - val_loss: 0.1686 - val_accuracy: 0.9350
# Epoch 89/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1751 - accuracy: 0.9274 - val_loss: 0.1683 - val_accuracy: 0.9350
# Epoch 90/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1745 - accuracy: 0.9290 - val_loss: 0.1675 - val_accuracy: 0.9350
# Epoch 91/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1739 - accuracy: 0.9302 - val_loss: 0.1669 - val_accuracy: 0.9370
# Epoch 92/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1734 - accuracy: 0.9300 - val_loss: 0.1663 - val_accuracy: 0.9370
# Epoch 93/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1728 - accuracy: 0.9300 - val_loss: 0.1658 - val_accuracy: 0.9370
# Epoch 94/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1721 - accuracy: 0.9302 - val_loss: 0.1653 - val_accuracy: 0.9380
# Epoch 95/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1715 - accuracy: 0.9306 - val_loss: 0.1646 - val_accuracy: 0.9380
# Epoch 96/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1709 - accuracy: 0.9310 - val_loss: 0.1641 - val_accuracy: 0.9380
# Epoch 97/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1703 - accuracy: 0.9310 - val_loss: 0.1634 - val_accuracy: 0.9400
# Epoch 98/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1697 - accuracy: 0.9324 - val_loss: 0.1630 - val_accuracy: 0.9390
# Epoch 99/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1691 - accuracy: 0.9318 - val_loss: 0.1625 - val_accuracy: 0.9390
# Epoch 100/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1685 - accuracy: 0.9328 - val_loss: 0.1617 - val_accuracy: 0.9400

# %%
## Plot of the ground truth set
import matplotlib.pyplot as plt
plt.scatter(inputs_dev[:, 0], inputs_dev[:, 1], c=targets_dev)
plt.show()

# %%
## Plot of your new model
import matplotlib.pyplot as plt
res1 = model.predict(inputs_dev)
decision1 = res1 > .5
plt.scatter(inputs_dev[:, 0], inputs_dev[:, 1], c=decision1)
plt.show()
# Out:
# 32/32 [==============================] - 0s 2ms/step

# %% [markdown]
# ## Q2 We will use the Boston housing data for Q2

# %%
from tensorflow.keras.datasets import boston_housing
(train_data, train_targets), (test_data, test_targets) = boston_housing.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/boston_housing.npz
# 57026/57026 [==============================] - 0s 0us/step

# %%
mean = train_data.mean(axis=0)
train_data -= mean
std = train_data.std(axis=0)
train_data /= std
test_data -= mean
test_data /= std

# %%
train_data.shape
# Out:
# (404, 13)

# %%
import numpy as np 

indices_permutation = np.random.permutation(404)
shuffled_x_train = train_data[indices_permutation]
shuffled_train_targets = train_targets[indices_permutation]

num_validation_samples = 54

## Complete the code below: 
val_x = shuffled_x_train[:54] ## take first 54 samples of shuffled_x_train 
val_targets = shuffled_train_targets[:54] ## take first 54 samples of shuffled_train_targets 


trn_x = shuffled_x_train[num_validation_samples:]
trn_targets = shuffled_train_targets[num_validation_samples:]

# %% [markdown]
# #### (Q2-1) [16 points] Design your neural network model with the structure below
#
# - We have two hidden Dense layers and one output layer as described below.
#   - [4] Try to make your model using functional API
#   - [4] Setup output sizes as 10 and 10 for hidden dense layers with relu activation.
#   - [4] Setup appropriate output dense layer for this regression problem.
#   - [4] For compile your model, let's use the RMSprop optimizer and specify the MSE as the loss function. For evaluation metrics, let's use MAE and MSE.
#
# ![image.png](data:image/png;base64,...)

# %%
trn_x.shape
# Out:
# (350, 13)

# %%
from tensorflow import keras
from tensorflow.keras import layers
  
# define your model here using Functional API 
inputs = keras.Input(shape=(13,), name="input")
features = layers.Dense(10, activation="relu")(inputs)
features = layers.Dense(10, activation="relu")(features)
outputs = layers.Dense(1)(features)
model = keras.Model(inputs=inputs, outputs=outputs)

  # compile your model
model.compile(optimizer="rmsprop",
              loss="mse",
              metrics=[["mae"], ["mse"]])

# %%
model.summary()
# Out:
# Model: "model_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  my_input (InputLayer)       [(None, 13)]              0
#
#  dense_45 (Dense)            (None, 10)                140
#
#  dense_46 (Dense)            (None, 10)                110
#
#  dense_47 (Dense)            (None, 1)                 11
#
# =================================================================
# Total params: 261
# Trainable params: 261
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### (Q2-2) [16 points] Fit your model.
# - [4] Use epoch size of 100, and batch size of 50.
# - [4] Use trn_x and trn_targets as training data
# - [4] Use val_x and val_targets as validation data
# - [4] Use ModelCheckpoint callback. Save the best one with respect to validation MAE.

# %%
## Define your callback here
callbacks_list = [    
        keras.callbacks.EarlyStopping(
        monitor="mae",
        patience=2,
    ),
    keras.callbacks.ModelCheckpoint(
        filepath="checkpoint_path.keras",
        monitor="mae",
        save_best_only=True,
    )
]

## fit your model
history = model.fit(
    trn_x, trn_targets,
    epochs=100,
    batch_size=50,
    validation_data=(val_x, val_targets))

# %%
## Visualizing training result
import matplotlib.pyplot as plt
val_loss = history.history["val_mae"]
trn_loss = history.history["mae"]
epochs = range(1, 101)
plt.plot(epochs, val_loss, "b--",
         label="Validation MAE")
plt.plot(epochs, trn_loss, "r-",
         label="Training MAE")
plt.title("MAE")
plt.xlabel("Epochs")
plt.ylabel("MAE")
plt.ylim([1,25])
plt.legend()

# %% [markdown]
# #### (Q2-3) [8 points] Load the best model from your callback checkpoint. Evaluate your model on test data.
# - [4] Load the best model from your ModelCheckpoint callback
# - [4] Report the MAE and MSE score on test data

# %%
## Load the best model, and use model.evaluate to get MAE and MSE scores.
test_loss, test_mae, test_mse = model.evaluate(val_x, val_targets)
print(f"[{test_loss}, {test_mae}, {test_mse}]")
# Out:
# 2/2 [==============================] - 0s 9ms/step - loss: 15.6716 - mae: 2.9543 - mse: 15.6716
# [15.671628952026367, 2.9542951583862305, 15.671628952026367]

# %% [markdown]
# #### (Q2-4) [15 points] Assuming that you have the Boston housing prices from 5 years ago, we have generated a fake dataset as below.

# %%
## house price 5 years ago
trn_price_5years_ago = trn_targets - 5 + np.random.random(len(trn_targets))*5 
val_price_5years_ago = val_targets - 5 + np.random.random(len(val_targets))*5

# %% [markdown]
# We would like to create a multi-input model with 'Boston housing prices from 5 years ago' as input2. Try to make your model as below.
#
# ![image.png](data:image/png;base64,...)

# %%
from tensorflow import keras
from tensorflow.keras import layers

## Your model here

input = keras.Input(shape=(13,), name="my_input1")
inputs2 = keras.Input(shape=(1,), name="my_input2")

features = layers.Dense(10, activation="relu")(inputs)
features = layers.Dense(10, activation="relu")(features)
concatenate = layers.Concatenate(name="concatenate_1")([features, inputs2])
outputs = layers.Dense(1)(concatenate)
model = keras.Model(inputs=[inputs, inputs2], outputs=outputs)

## Compile your model
model.compile(optimizer="rmsprop",
              loss="mse",
              metrics=[["mae"], ["mse"]])
model.summary()
# Out:
# Model: "model_14"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input (InputLayer)             [(None, 13)]         0           []
#
#  dense_68 (Dense)               (None, 10)           140         ['input[0][0]']
#
#  dense_69 (Dense)               (None, 10)           110         ['dense_68[0][0]']
#
#  my_input2 (InputLayer)         [(None, 1)]          0           []
#
#  concatenate_1 (Concatenate)    (None, 11)           0           ['dense_69[0][0]',
#                                                                   'my_input2[0][0]']
#
#  dense_70 (Dense)               (None, 1)            12          ['concatenate_1[0][0]']
#
# ==================================================================================================
# Total params: 262
# Trainable params: 262
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
## Your model may look like this.
keras.utils.plot_model(model, "model2.png", show_shapes=True)

# %%
trn_price_5years_ago.reshape(-1)

# %%
## Fit your model 
    ## Specify training data, validation data
trn_price_5years_ago.reshape(-1)
val_price_5years_ago.reshape(-1)

history = model.fit( trn_x,[trn_targets, trn_price_5years_ago],
                    epochs=100,
                    batch_size=50,
                    validation_data=(val_y,[val_targets, val_price_5years_ago]))
# Out:
# Epoch 1/100
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-109-affd19ca66f8> in <cell line: 6>()
#       4 val_price_5years_ago.reshape(-1)
#       5
# ----> 6 history = model.fit([trn_targets, trn_price_5years_ago], trn_x,
#       7                     epochs=100,
#       8                     batch_size=50,
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.9/dist-packages/keras/engine/training.py in tf__train_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16                 except:
#      17                     do_return = False
#
# ValueError: in user code:
#
#     File "/usr/local/lib/python3.9/dist-packages/keras/engine/training.py", line 1284, in train_function  *
#         return step_function(self, iterator)
#     File "/usr/local/lib/python3.9/dist-packages/keras/engine/training.py", line 1268, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/usr/local/lib/python3.9/dist-packages/keras/engine/training.py", line 1249, in run_step  **
#         outputs = model.train_step(data)
#     File "/usr/local/lib/python3.9/dist-packages/keras/engine/training.py", line 1050, in train_step
#         y_pred = self(x, training=True)
#     File "/usr/local/lib/python3.9/dist-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/usr/local/lib/python3.9/dist-packages/keras/engine/input_spec.py", line 253, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Exception encountered when calling layer 'model_14' (type Functional).
#
#     Input 0 of layer "dense_68" is incompatible with the layer: expected min_ndim=2, found ndim=1. Full shape received: (50,)
#
#     Call arguments received by layer 'model_14' (type Functional):
#       • inputs=('tf.Tensor(shape=(50,), dtype=float32)', 'tf.Tensor(shape=(50,), dtype=float32)')
#       • training=True
#       • mask=None

# %%
import matplotlib.pyplot as plt
val_loss = history.history["val_mae"]
trn_loss = history.history["mae"]
epochs = range(1, 101)
plt.plot(epochs, val_loss, "b--",
         label="Validation MAE")
plt.plot(epochs, trn_loss, "r-",
         label="Training MAE")
plt.title("MAE")
plt.xlabel("Epochs")
plt.ylabel("MAE")
plt.ylim([1,25])
plt.legend()
